# %%
import numpy as np 

import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
 df=pd.read_csv('H:\\0_tumbleRateInEachRadialDistance.csv')
x=df.iloc[:,0]
a = df.iloc[:,1] 
b = df.iloc[:,2] 
c = df.iloc[:,3]

# %%
__author__ = 'vafadar'

__version__ = '1.0'


fig = plt.figure(figsize=(10,10))
plt.rcParams.update({'font.family': 'Arial'})
plt.rcParams.update({'font.size': 30})
ax = fig.add_subplot(111)
ax.spines['right'].set_visible(True)
ax.spines['top'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(True)
ax.spines['left'].set_linewidth(3)
ax.spines['bottom'].set_linewidth(3)
ax.spines['right'].set_linewidth(3)
ax.spines['top'].set_linewidth(3)
ax.spines['bottom'].set_color('black')
ax.spines['left'].set_color('black')

# put your x and y arrays or lists here.        


ax.errorbar(x, b, lw=5, label=r'SML')
ax.errorbar(x, a, lw=5, label=r'NHRW')
ax.errorbar(x, c, lw=5, label=r'Nikhil Mittal')
#fig = plt.figure()
#ax = fig.add_subplot(111)
#ax.plot(x,a,'k--',x,b,'k:',x,c,'k')


handles, labels = ax.get_legend_handles_labels()

ax.legend(handles,labels, loc='best', fontsize='medium', \
          handlelength=0.5, handletextpad=0.4, framealpha=0., labelspacing=0.1,\
          numpoints=1, markerscale=0.3,  fancybox=False, edgecolor='white')

plt.tick_params(axis='x', which='both', bottom=True, top=False,
    labelbottom=True, size=20, width=3, direction='out', pad=25, colors='black')
plt.tick_params(axis='y', which='both', left=True, right=False,
    labelbottom=True, size=20, width=3, direction='out', pad=25, colors='black')

# X and Y labels (you can use latex math symbols as well, e.g. $\alpha = 0.2$)
plt.ylabel(r'Tumble Frequency (Hz)', fontsize= 50, labelpad=20)
plt.xlabel(r'Relative Distance', fontsize= 50, labelpad=20)

#plt.tight_layout()


plt.yticks(np.arange(0, 100, 25))
plt.xticks(np.arange(0, 8, 3))

plt.ylim(-10, 100)
plt.xlim(-1, 9)


plt.savefig('h:\\angleDistanceCorrelation.png', bbox_inches='tight', dpi=300)
plt.show()
