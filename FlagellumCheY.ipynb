# %%
import numpy as np 
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
x=  np.arange(0., 30., 0.02)
a = mlab.normpdf(x, 13, 7)*10
b = mlab.normpdf(x, 2, 4)*10
c = (a/(a+b))
# Out:
# C:\Users\Safa\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
#
# C:\Users\Safa\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
__author__ = 'vafadar'

__version__ = '1.0'


fig = plt.figure(figsize=(10,10))
plt.rcParams.update({'font.family': 'Arial'})
plt.rcParams.update({'font.size': 30})
ax = fig.add_subplot(111)
ax.spines['right'].set_visible(True)
ax.spines['top'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.spines['left'].set_visible(True)
ax.spines['left'].set_linewidth(3)
ax.spines['bottom'].set_linewidth(3)
ax.spines['right'].set_linewidth(3)
ax.spines['top'].set_linewidth(3)
ax.spines['bottom'].set_color('black')
ax.spines['left'].set_color('black')

# put your x and y arrays or lists here.        

ax.errorbar(x, a, lw=5, label=r'CW')
ax.errorbar(x, b, lw=5, label=r'CWW')
ax.errorbar(x, c, lw=5, label=r'Probability CCW')
#fig = plt.figure()
#ax = fig.add_subplot(111)
#ax.plot(x,a,'k--',x,b,'k:',x,c,'k')


handles, labels = ax.get_legend_handles_labels()

ax.legend(handles,labels, loc=(0.55,0.7), fontsize='small', \
          handlelength=0.5, handletextpad=0.4, framealpha=0., labelspacing=0.1,\
          numpoints=1, markerscale=0.3,  fancybox=False, edgecolor='white')

plt.tick_params(axis='x', which='both', bottom=True, top=False,
    labelbottom=True, size=20, width=3, direction='out', pad=25, colors='black')
plt.tick_params(axis='y', which='both', left=True, right=False,
    labelbottom=True, size=20, width=3, direction='out', pad=25, colors='black')



#plt.tight_layout()




plt.savefig('h:\\FlagellumCheY.png', bbox_inches='tight', dpi=300)
plt.show()
